# %%
def normalize(np_array):
    
    # 第一步：取绝对值
    abs_arr = np.abs(np_array)
    
    # 第二步：归一化，这里采用除以和的方式
    arr_sum = abs_arr.sum()
    normalized_arr = abs_arr / arr_sum
    
    # 第三步：将等于0的位置替换为1e-8
    final_arr = np.where(normalized_arr == 0, 1e-8, normalized_arr)
    return final_arr

# %%
from scipy.stats import entropy,pearsonr

def KL(dst_dist, src_dist):
    t=entropy(dst_dist, src_dist)
    return t.sum()/len(t)

def cosine_similarity(a, b):
    a_norm = np.linalg.norm(a.flatten())
    b_norm = np.linalg.norm(b.flatten())
    cos_sim = np.dot(a.flatten(), b.flatten()) / (a_norm * b_norm)
    return cos_sim

# %%
def topk_row(matrix,k=5):
    # 计算每一行的和
    row_sums = matrix.sum(axis=1)
    # 获取按行和排序的行索引
    sorted_indices = np.argsort(row_sums)[::-1]

    return sorted_indices[:k]

def topk_column(matrix,k=5):
    return topk_row(matrix.T,k)

# %%
from tqdm import tqdm
from scipy.stats._mstats_basic import winsorize
import matplotlib.pyplot as plt
import numpy as np
import json_lines, json
import os

root="../lrp_result_llama_7b"
non_hallucinations=[]
hallucinations=[]
for p in os.listdir(root):
    path=os.path.join(root,p)
    if p.split('-')[-1].startswith('0'):
        non_hallucinations.append(path)
    if p.split('-')[-1].startswith('1'):
        hallucinations.append(path)

def get_relevance(json_path):
    with open(json_path, 'r') as f:
        data = json.load(f)
        prompt_ids,response_ids=data["prompt_ids"][0],data["response_ids"][0]
        prompt_length,response_length=len(prompt_ids),len(response_ids)
        relevance=data["relevance"]
        source2dst_relevance=[x[:prompt_length] for x in relevance]
        source_relevance=list(np.array(source2dst_relevance).mean(axis=0))
        dst_relevance=list(np.array(source2dst_relevance).mean(axis=-1))
       
    return np.array(source2dst_relevance),np.array(source_relevance),np.array(dst_relevance)

from collections import defaultdict

def calculate_averages(arrays,reverse=False):
    # 初始化字典
    if reverse:
        arrays=[list(reversed(x)) for x in arrays]
    sums = defaultdict(int)
    counts = defaultdict(int)

    # 更新总和和计数
    for arr in arrays:
        for i, num in enumerate(arr):
            sums[i] += num
            counts[i] += 1

    # 计算平均值
    max_index = max(counts)
   
    averages = [sums[i] / counts[i] if i in counts else None for i in range(max_index + 1)]
    if reverse:
        averages=list(reversed(averages))
    return averages

def average_segments(arr, new_length):
    # 确定原数组长度
    old_length = len(arr)
    
    # 计算比例因子
    ratio = old_length / new_length
    
    # 初始化新数组
    new_arr = []
    
    # 遍历并计算每个区间的均值
    for i in range(new_length):
        start_index = int(i * ratio)
        end_index = int((i + 1) * ratio)
        
        # 计算均值
        segment_sum = sum(arr[start_index:end_index])
        segment_avg = segment_sum / (end_index - start_index) if end_index > start_index else 0
        
        # 添加到新数组
        new_arr.append(segment_avg)
    
    return new_arr
def average_segments_2d(arr_2d, new_rows, new_cols):
    # 获取二维数组的行数和列数
    rows, cols = arr_2d.shape[0], arr_2d.shape[1]

    # 计算行和列的比例因子
    row_ratio = rows / new_rows
    col_ratio = cols / new_cols

    # 初始化新的二维数组
    new_arr_2d = []

    # 遍历新行
    for i in range(new_rows):
        new_row = []
        # 计算当前行的起始和结束索引
        start_row_index = int(i * row_ratio)
        end_row_index = int((i + 1) * row_ratio)

        # 遍历新列
        for j in range(new_cols):
            # 计算当前列的起始和结束索引
            start_col_index = int(j * col_ratio)
            end_col_index = int((j + 1) * col_ratio)

            # 计算均值
            segment_sum = 0
            count = 0
            for r in range(start_row_index, end_row_index):
                for c in range(start_col_index, end_col_index):
                    if r < rows and c < cols:  # 确保索引有效
                        segment_sum += arr_2d[r][c]
                        count += 1

            segment_avg = segment_sum / count if count > 0 else 0

            # 添加到新行
            new_row.append(segment_avg)

        # 添加新行到新数组
        new_arr_2d.append(new_row)

    return np.array(new_arr_2d)
def abs_list(arr):
    return list(np.abs(np.array(arr)))
# 使用 winsorize 函数去除极值点
h_contributions,nonh_contributions=[],[]
h_contributions_s,nonh_contributions_s=[],[]
h_contributions_d,nonh_contributions_d=[],[]
for path in tqdm(hallucinations):
    source2dst_contribution,source_contribution,dst_contribution=get_relevance(path)
    if source2dst_contribution.shape[0]<200 or source2dst_contribution.shape[1]<200:
        continue
    h_contributions_s.append(average_segments(source_contribution,110))
    h_contributions_d.append(average_segments(dst_contribution,110))
    h_contributions.append(np.array(average_segments_2d(source2dst_contribution,110,110)))
for path in tqdm(non_hallucinations):
    source2dst_contribution,source_contribution,dst_contribution=get_relevance(path)
    if source2dst_contribution.shape[0]<200 or source2dst_contribution.shape[1]<200:
        continue
    nonh_contributions_s.append(average_segments(source_contribution,110))
    nonh_contributions_d.append(average_segments(dst_contribution,110))
    nonh_contributions.append(np.array(average_segments_2d(source2dst_contribution,110,110)))


# 求均值，去除极值
h_contributions_s_mean=np.array(h_contributions_s).mean(axis=0)
nonh_contributions_s_mean=np.array(nonh_contributions_s).mean(axis=0)
nonh_contributions_s_mean=nonh_contributions_s_mean[5:-5]
h_contributions_s_mean=h_contributions_s_mean[5:-5]

h_contributions_d_mean=np.array(h_contributions_d).mean(axis=0)
nonh_contributions_d_mean=np.array(nonh_contributions_d).mean(axis=0)
nonh_contributions_d_mean=nonh_contributions_d_mean[5:-5]
h_contributions_d_mean=h_contributions_d_mean[5:-5]

h_contributions_mean=np.array(h_contributions).mean(axis=0)
nonh_contributions_mean=np.array(nonh_contributions).mean(axis=0)
nonh_contributions_mean=nonh_contributions_mean[5:-5,5:-5]
h_contributions_mean=h_contributions_mean[5:-5,5:-5]
# Out:
# 100%|██████████| 510/510 [00:32<00:00, 15.73it/s]
# 100%|██████████| 479/479 [00:26<00:00, 18.42it/s]

# %%
from tqdm import tqdm
import numpy as np
import json_lines, json
import os

root2="../lrp_result_llama_13b"
non_hallucinations2=[]
hallucinations2=[]
for p in os.listdir(root2):
    path=os.path.join(root2,p)
    if p.split('-')[-1].startswith('0'):
        non_hallucinations2.append(path)
    if p.split('-')[-1].startswith('1'):
        hallucinations2.append(path)

from collections import defaultdict
# 使用 winsorize 函数去除极值点
h_contributions2,nonh_contributions2=[],[]
h_contributions_s2,nonh_contributions_s2=[],[]
h_contributions_d2,nonh_contributions_d2=[],[]
for path in tqdm(hallucinations2):
    source2dst_contribution,source_contribution,dst_contribution=get_relevance(path)
    if source2dst_contribution.shape[0]<200 or source2dst_contribution.shape[1]<200:
        continue
    h_contributions_s2.append(average_segments(source_contribution,110))
    h_contributions_d2.append(average_segments(dst_contribution,110))
    h_contributions2.append(np.array(average_segments_2d(source2dst_contribution,110,110)))
for path in tqdm(non_hallucinations2):
    source2dst_contribution,source_contribution,dst_contribution=get_relevance(path)
    if source2dst_contribution.shape[0]<200 or source2dst_contribution.shape[1]<200:
        continue
    nonh_contributions_s2.append(average_segments(source_contribution,110))
    nonh_contributions_d2.append(average_segments(dst_contribution,110))
    nonh_contributions2.append(np.array(average_segments_2d(source2dst_contribution,110,110)))


# 求均值，去除极值
h_contributions_s_mean2=np.array(h_contributions_s2).mean(axis=0)
nonh_contributions_s_mean2=np.array(nonh_contributions_s2).mean(axis=0)
nonh_contributions_s_mean2=nonh_contributions_s_mean2[5:-5]
h_contributions_s_mean2=h_contributions_s_mean2[5:-5]

h_contributions_d_mean2=np.array(h_contributions_d2).mean(axis=0)
nonh_contributions_d_mean2=np.array(nonh_contributions_d2).mean(axis=0)
nonh_contributions_d_mean2=nonh_contributions_d_mean2[5:-5]
h_contributions_d_mean2=h_contributions_d_mean2[5:-5]

h_contributions_mean2=np.array(h_contributions2).mean(axis=0)
nonh_contributions_mean2=np.array(nonh_contributions2).mean(axis=0)
nonh_contributions_mean2=nonh_contributions_mean2[5:-5,5:-5]
h_contributions_mean2=h_contributions_mean2[5:-5,5:-5]
# Out:
# 100%|██████████| 399/399 [00:19<00:00, 20.69it/s]
# 100%|██████████| 590/590 [00:21<00:00, 27.64it/s]

# %%
def normalize(m):
    min_val = np.min(m)
    max_val = np.max(m)
    normalized_matrix = (m - min_val) / (max_val - min_val)
    return normalized_matrix

# %%
# 箱线图
h_contributions_s_box=[sum(normalize(x[5:-5]))/100 for x in h_contributions_s]
h_contributions_d_box=[sum(normalize(x[5:-5]))/100 for x in h_contributions_d]
nonh_contributions_s_box=[sum(normalize(x[5:-5]))/100 for x in nonh_contributions_s]
nonh_contributions_d_box=[sum(normalize(x[5:-5]))/100 for x in nonh_contributions_d]

h_contributions_s_box2=[sum(normalize(x[5:-5]))/100 for x in h_contributions_s2]
h_contributions_d_box2=[sum(normalize(x[5:-5]))/100 for x in h_contributions_d2]
nonh_contributions_s_box2=[sum(normalize(x[5:-5]))/100 for x in nonh_contributions_s2]
nonh_contributions_d_box2=[sum(normalize(x[5:-5]))/100 for x in nonh_contributions_d2]

# 创建子图
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(15, 15))

# 创建箱线图数据
data = [h_contributions_s_box,nonh_contributions_s_box, h_contributions_d_box,  nonh_contributions_d_box]

data2 = [h_contributions_s_box2,nonh_contributions_s_box2, h_contributions_d_box2,  nonh_contributions_d_box2]

# 创建箱线图
bp=ax1.boxplot(data, labels=['Source Relevance\n(Hallucination)', 'Source Relevance\n(Normal)', 'Response Relevance\n(Hallucination)', 'Response Relevance\n(Normal)'])\
# 自定义异常值的样式
plt.setp(bp['fliers'], marker='o', markersize=4, markerfacecolor='blue', markeredgecolor='lightblue')
plt.rcParams['font.size'] = 20

# 添加标题和轴标签
ax1.set_xlabel('Hallucination/Normal')
ax1.set_ylabel('Relevance')
ax1.set_title('Llama-7B')

# 创建箱线图
bp2=ax2.boxplot(data2, labels=['Source Relevance\n(Hallucination)', 'Source Relevance\n(Normal)', 'Response Relevance\n(Hallucination)', 'Response Relevance\n(Normal)'])\
# 自定义异常值的样式
plt.setp(bp2['fliers'], marker='o', markersize=6, markerfacecolor='blue', markeredgecolor='lightblue')

# 添加标题和轴标签
ax2.set_xlabel('Hallucination/Normal')
ax2.set_ylabel('Relevance')
ax2.set_title('Llama-13B')

# 显示图形
plt.tight_layout()

plt.savefig('../pdf/box.pdf')
# 显示图形
plt.show()
# Out:
# /var/folders/m0/bq55cd_d4ks7fz_vnjvd5ykm0000gp/T/ipykernel_22740/858607228.py:21: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bp=ax1.boxplot(data, labels=['Source Relevance\n(Hallucination)', 'Source Relevance\n(Normal)', 'Response Relevance\n(Hallucination)', 'Response Relevance\n(Normal)'])\
# /var/folders/m0/bq55cd_d4ks7fz_vnjvd5ykm0000gp/T/ipykernel_22740/858607228.py:32: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bp2=ax2.boxplot(data2, labels=['Source Relevance\n(Hallucination)', 'Source Relevance\n(Normal)', 'Response Relevance\n(Hallucination)', 'Response Relevance\n(Normal)'])\

# %%
import numpy as np

def random_sample_rows(array, size):
    """
    从二维数组中随机抽取指定数量的行。

    :param array: 二维数组
    :param num_samples: 抽取的行数
    :return: 包含随机抽取行的新数组
    """
    # 获取第一个维度的长度
    num_rows = len(array)

    # 随机选择行索引
    selected_rows = np.random.choice(num_rows, size=size, replace=False)

    # 根据选中的行索引获取对应的行
    sample = list(np.array(array)[selected_rows])

    return sample

# %%
import numpy as np
from scipy.stats import mannwhitneyu

# U检验
h_contributions_s_mannwhitneyu=[normalize(x[5:-5]) for x in h_contributions_s]
h_contributions_d_mannwhitneyu=[normalize(x[5:-5]) for x in h_contributions_d]
nonh_contributions_s_mannwhitneyu=[normalize(x[5:-5]) for x in nonh_contributions_s]
nonh_contributions_d_mannwhitneyu=[normalize(x[5:-5]) for x in nonh_contributions_d]

h_contributions_s_mannwhitneyu2=[normalize(x[5:-5]) for x in h_contributions_s2]
h_contributions_d_mannwhitneyu2=[normalize(x[5:-5]) for x in h_contributions_d2]
nonh_contributions_s_mannwhitneyu2=[normalize(x[5:-5]) for x in nonh_contributions_s2]
nonh_contributions_d_mannwhitneyu2=[normalize(x[5:-5]) for x in nonh_contributions_d2]

mannwhitneyu_median_hs=[]
mannwhitneyu_median_nonhs=[]
mannwhitneyu_median_hs2=[]
mannwhitneyu_median_nonhs2=[]

for _ in range(50):
    
    # 对每一列进行Mann-Whitney U检验
    results = []
    for col1, col2 in zip(random_sample_rows(h_contributions_s_mannwhitneyu,size=100), random_sample_rows(nonh_contributions_s_mannwhitneyu,size=100)):
        statistic, pvalue = mannwhitneyu(np.array(col1), np.array(col2), alternative='two-sided')
        results.append((statistic, pvalue))
    
    # 求平均
    print(f"source relevance llama-7b: avg pvalue is {sum([x[1] for x in results])/len(results)}, min pvalue is {min([x[1] for x in results])}, max pvalue is {max([x[1] for x in results])}, median pvalue is {np.median([x[1] for x in results])}")
    
    mannwhitneyu_median_hs.append(np.median([x[1] for x in results]))
    
    # 对每一列进行Mann-Whitney U检验
    results = []
    for col1, col2 in zip(random_sample_rows(h_contributions_d_mannwhitneyu,size=200), random_sample_rows(nonh_contributions_d_mannwhitneyu,size=200)):
        statistic, pvalue = mannwhitneyu(np.array(col1), np.array(col2), alternative='two-sided')
        results.append((statistic, pvalue))
    
    # 求平均
    print(f"response relevance llama-7b avg pvalue is {sum([x[1] for x in results])/len(results)}, min pvalue is {min([x[1] for x in results])}, max pvalue is {max([x[1] for x in results])}, median pvalue is {np.median([x[1] for x in results])}")
    
    mannwhitneyu_median_nonhs.append(np.median([x[1] for x in results]))
    
    # 对每一列进行Mann-Whitney U检验
    results = []
    for col1, col2 in zip(random_sample_rows(h_contributions_s_mannwhitneyu2,size=200), random_sample_rows(nonh_contributions_s_mannwhitneyu2,size=200)):
        statistic, pvalue = mannwhitneyu(np.array(col1), np.array(col2), alternative='two-sided')
        results.append((statistic, pvalue))
    
    # 求平均
    print(f"source relevance llama-13b avg pvalue is {sum([x[1] for x in results])/len(results)}, min pvalue is {min([x[1] for x in results])}, max pvalue is {max([x[1] for x in results])}, median pvalue is {np.median([x[1] for x in results])}")
    
    mannwhitneyu_median_hs2.append(np.median([x[1] for x in results]))
    
    # 对每一列进行Mann-Whitney U检验
    results = []
    for col1, col2 in zip(random_sample_rows(h_contributions_d_mannwhitneyu2,size=200), random_sample_rows(nonh_contributions_d_mannwhitneyu2,size=200)):
        statistic, pvalue = mannwhitneyu(np.array(col1), np.array(col2), alternative='two-sided')
        results.append((statistic, pvalue))
    
    # 求平均
    print(f"response relevance llama-13b avg pvalue is {sum([x[1] for x in results])/len(results)}, min pvalue is {min([x[1] for x in results])}, max pvalue is {max([x[1] for x in results])}, median pvalue is {np.median([x[1] for x in results])}")
    
    mannwhitneyu_median_nonhs2.append(np.median([x[1] for x in results]))
# Out:
# source relevance llama-7b: avg pvalue is 0.14346633871996897, min pvalue is 5.797228057041549e-22, max pvalue is 0.9425382216309044, median pvalue is 0.011727578598687137
# response relevance llama-7b avg pvalue is 0.166949190753761, min pvalue is 1.3317077774214715e-20, max pvalue is 0.995126170981771, median pvalue is 0.015359130243834066
# source relevance llama-13b avg pvalue is 0.1819554494304378, min pvalue is 3.27602487346742e-25, max pvalue is 0.9231124083101084, median pvalue is 0.013926435463694932
# response relevance llama-13b avg pvalue is 0.21280917149262119, min pvalue is 9.680839197719483e-10, max pvalue is 0.9912272299746749, median pvalue is 0.06384084207780438
# source relevance llama-7b: avg pvalue is 0.18466929593604087, min pvalue is 2.108209529898583e-23, max pvalue is 0.9931766801106002, median pvalue is 0.04187136160732524
# response relevance llama-7b avg pvalue is 0.19749886794349678, min pvalue is 3.791472626028683e-16, max pvalue is 0.9873284984571858, median pvalue is 0.05014651377636499
# source relevance llama-13b avg pvalue is 0.14880389845014463, min pvalue is 7.325847454320676e-29, max pvalue is 0.9795320362158361, median pvalue is 0.009300732241432401
# response relevance llama-13b avg pvalue is 0.24370455199612476, min pvalue is 2.417349835857888e-15, max pvalue is 0.9990252283768458, median pvalue is 0.081315391406869
# source relevance llama-7b: avg pvalue is 0.1825633003123689, min pvalue is 8.799018253400242e-20, max pvalue is 0.9814809975952034, median pvalue is 0.027925709737355114
# response relevance llama-7b avg pvalue is 0.22234264502947912, min pvalue is 8.905404387947167e-12, max pvalue is 0.9912272299746749, median pvalue is 0.06262719836621253
# source relevance llama-13b avg pvalue is 0.16416399191593456, min pvalue is 4.0868200721094616e-23, max pvalue is 0.9639457195943646, median pvalue is 0.0156706471142279
# response relevance llama-13b avg pvalue is 0.228086921681751, min pvalue is 7.097265028975828e-17, max pvalue is 0.9931766801106002, median pvalue is 0.07173793822862495
# source relevance llama-7b: avg pvalue is 0.18338345420532243, min pvalue is 2.460383778985958e-18, max pvalue is 0.9814809975952034, median pvalue is 0.019898420501149157
# response relevance llama-7b avg pvalue is 0.2121086920329517, min pvalue is 2.4949652099958306e-13, max pvalue is 0.9970756909500667, median pvalue is 0.0494779884919858
# source relevance llama-13b avg pvalue is 0.15013704911843728, min pvalue is 7.954565794302224e-29, max pvalue is 0.995126170981771, median pvalue is 0.0075987712608440675
# response relevance llama-13b avg pvalue is 0.23743576076449177, min pvalue is 6.526180198466023e-16, max pvalue is 0.9639457195943646, median pvalue is 0.08234314015516862
# source relevance llama-7b: avg pvalue is 0.14076730601257278, min pvalue is 3.742720487483711e-26, max pvalue is 0.9970756909500667, median pvalue is 0.0043587666059773204
# response relevance llama-7b avg pvalue is 0.19380106030119063, min pvalue is 4.546027489891312e-16, max pvalue is 0.9873284984571858, median pvalue is 0.03966124585531133
# source relevance llama-13b avg pvalue is 0.19022913521039428, min pvalue is 1.4756150986162717e-29, max pvalue is 0.9990252283768458, median pvalue is 0.013003369004783976
# response relevance llama-13b avg pvalue is 0.22111267009853633, min pvalue is 8.046752102100655e-13, max pvalue is 0.9931766801106002, median pvalue is 0.09443443408838594
# source relevance llama-7b: avg pvalue is 0.1908710633595409, min pvalue is 3.8918448045225835e-23, max pvalue is 0.9931766801106002, median pvalue is 0.01420575886686961
# response relevance llama-7b avg pvalue is 0.1647882461939664, min pvalue is 1.1869861608917973e-20, max pvalue is 0.9931766801106002, median pvalue is 0.03252577710304657
# source relevance llama-13b avg pvalue is 0.16074525151511954, min pvalue is 1.6649529328997023e-28, max pvalue is 0.995126170981771, median pvalue is 0.008040478984012795
# response relevance llama-13b avg pvalue is 0.26443793764550183, min pvalue is 1.036381210065948e-10, max pvalue is 0.9853792403473814, median pvalue is 0.09959009092547208
# source relevance llama-7b: avg pvalue is 0.15129260553193183, min pvalue is 6.502126749493173e-31, max pvalue is 0.9076041504611124, median pvalue is 0.016145111295735724
# response relevance llama-7b avg pvalue is 0.20710085867571457, min pvalue is 5.451926562709507e-18, max pvalue is 0.995126170981771, median pvalue is 0.036926173102891834
# source relevance llama-13b avg pvalue is 0.17577858790262432, min pvalue is 4.22961729161034e-25, max pvalue is 0.9795320362158361, median pvalue is 0.012096540423341438
# response relevance llama-13b avg pvalue is 0.23556957882689705, min pvalue is 2.910299600469035e-12, max pvalue is 0.9697892943606978, median pvalue is 0.07061492314601375
# source relevance llama-7b: avg pvalue is 0.17804493035440452, min pvalue is 1.6477450770447064e-31, max pvalue is 0.9600510592493637, median pvalue is 0.011764891690234185
# response relevance llama-7b avg pvalue is 0.17493869491916617, min pvalue is 1.6415647895611275e-21, max pvalue is 1.0, median pvalue is 0.0280907395645224
# source relevance llama-13b avg pvalue is 0.1645134982473, min pvalue is 1.9618618746885395e-25, max pvalue is 0.9931766801106002, median pvalue is 0.004065101610518073
# response relevance llama-13b avg pvalue is 0.25195557796390317, min pvalue is 3.4591817793106544e-13, max pvalue is 0.9873284984571858, median pvalue is 0.08674646624762744
# source relevance llama-7b: avg pvalue is 0.1728137138469714, min pvalue is 2.8916986535699347e-24, max pvalue is 0.9328203136035664, median pvalue is 0.02831902104019554
# response relevance llama-7b avg pvalue is 0.2123827675072254, min pvalue is 8.397665427415504e-15, max pvalue is 0.995126170981771, median pvalue is 0.04460146839096946
# source relevance llama-13b avg pvalue is 0.2032986912245217, min pvalue is 3.892140318066339e-31, max pvalue is 0.9814809975952034, median pvalue is 0.011013198815822883
# response relevance llama-13b avg pvalue is 0.21876087533938132, min pvalue is 1.3374522567278896e-11, max pvalue is 0.9756344915935268, median pvalue is 0.0592550473087593
# source relevance llama-7b: avg pvalue is 0.18754457089487636, min pvalue is 1.3998720596580562e-18, max pvalue is 0.9912272299746749, median pvalue is 0.04306389283756064
# response relevance llama-7b avg pvalue is 0.19448821485369158, min pvalue is 2.6682697270073412e-17, max pvalue is 0.9990252283768458, median pvalue is 0.04137110582415349
# source relevance llama-13b avg pvalue is 0.16170314313368098, min pvalue is 1.359499697486828e-24, max pvalue is 0.9736859316010897, median pvalue is 0.010674156222461723
# response relevance llama-13b avg pvalue is 0.23590447466056483, min pvalue is 2.5123400891955712e-09, max pvalue is 0.9853792403473814, median pvalue is 0.05342761534135983
# source relevance llama-7b: avg pvalue is 0.18126888944321495, min pvalue is 8.406068808528936e-25, max pvalue is 0.9775831970064603, median pvalue is 0.02513896158667135
# response relevance llama-7b avg pvalue is 0.20541037933905149, min pvalue is 3.187545133222928e-18, max pvalue is 1.0, median pvalue is 0.036370213405226455
# source relevance llama-13b avg pvalue is 0.17802876020216257, min pvalue is 3.443781312287928e-23, max pvalue is 0.9990252283768458, median pvalue is 0.019819620266654556
# response relevance llama-13b avg pvalue is 0.21550023088108816, min pvalue is 2.6215634485759645e-12, max pvalue is 0.9736859316010897, median pvalue is 0.04772855351616566
# source relevance llama-7b: avg pvalue is 0.18899603741336768, min pvalue is 1.4306722490124215e-18, max pvalue is 0.9561573521070761, median pvalue is 0.005744018854548914
# response relevance llama-7b avg pvalue is 0.21303142263203179, min pvalue is 3.791472626028683e-16, max pvalue is 0.9990252283768458, median pvalue is 0.0463231912199667
# source relevance llama-13b avg pvalue is 0.16638907362808053, min pvalue is 8.195557458670594e-25, max pvalue is 0.9990252283768458, median pvalue is 0.011907867679210336
# response relevance llama-13b avg pvalue is 0.24889140166991194, min pvalue is 5.240169232209381e-12, max pvalue is 0.9736859316010897, median pvalue is 0.09347549375906888
# source relevance llama-7b: avg pvalue is 0.14415392005347463, min pvalue is 8.905713809470441e-23, max pvalue is 0.9912272299746749, median pvalue is 0.004844782669852678
# response relevance llama-7b avg pvalue is 0.22864267157650878, min pvalue is 9.16646389096571e-16, max pvalue is 0.9756344915935268, median pvalue is 0.05499485632299876
# source relevance llama-13b avg pvalue is 0.19610385319822254, min pvalue is 3.5524989077125866e-26, max pvalue is 0.9639457195943646, median pvalue is 0.029008319172439342
# response relevance llama-13b avg pvalue is 0.27595785057688527, min pvalue is 6.526180198466023e-16, max pvalue is 0.9736859316010897, median pvalue is 0.15126894818356867
# source relevance llama-7b: avg pvalue is 0.1532503279026369, min pvalue is 2.338493773285957e-26, max pvalue is 0.9522646908943472, median pvalue is 0.016502494175654154
# response relevance llama-7b avg pvalue is 0.22358043166374172, min pvalue is 7.551233940111951e-17, max pvalue is 0.9970756909500667, median pvalue is 0.06077884538883156
# source relevance llama-13b avg pvalue is 0.17380717964858364, min pvalue is 2.2191682197112118e-26, max pvalue is 0.9990252283768458, median pvalue is 0.011880560082974938
# response relevance llama-13b avg pvalue is 0.21611211979285078, min pvalue is 2.7422235471123967e-14, max pvalue is 0.9931766801106002, median pvalue is 0.07157576964318815
# source relevance llama-7b: avg pvalue is 0.15051906080113808, min pvalue is 2.3070852709892622e-24, max pvalue is 0.9912272299746749, median pvalue is 0.0028510240468622716
# response relevance llama-7b avg pvalue is 0.21434684722743313, min pvalue is 3.6521161414531574e-13, max pvalue is 0.9853792403473814, median pvalue is 0.04823761255495278
# source relevance llama-13b avg pvalue is 0.1848895567901302, min pvalue is 3.1178510240846077e-26, max pvalue is 0.958104080730776, median pvalue is 0.027542672727171643
# response relevance llama-13b avg pvalue is 0.21999640809075013, min pvalue is 6.264272803584873e-11, max pvalue is 0.9931766801106002, median pvalue is 0.08255960444329484
# source relevance llama-7b: avg pvalue is 0.1384072558665651, min pvalue is 1.1732575930363958e-17, max pvalue is 0.9873284984571858, median pvalue is 0.0086231735094649
# response relevance llama-7b avg pvalue is 0.1902518973095158, min pvalue is 5.332130287233386e-13, max pvalue is 0.9873284984571858, median pvalue is 0.04351608423186518
# source relevance llama-13b avg pvalue is 0.1458018093113927, min pvalue is 1.884728352429053e-19, max pvalue is 0.9931766801106002, median pvalue is 0.005132413509895747
# response relevance llama-13b avg pvalue is 0.23879250640944288, min pvalue is 6.097601228508055e-10, max pvalue is 0.9853792403473814, median pvalue is 0.10874680582911213
# source relevance llama-7b: avg pvalue is 0.12507629762523714, min pvalue is 5.742572824840488e-25, max pvalue is 0.9775831970064603, median pvalue is 0.005270797299951242
# response relevance llama-7b avg pvalue is 0.20450629567905648, min pvalue is 3.187545133222928e-18, max pvalue is 0.9853792403473814, median pvalue is 0.0647338460496084
# source relevance llama-13b avg pvalue is 0.1261923179611672, min pvalue is 1.8383215910696454e-22, max pvalue is 0.880552761041159, median pvalue is 0.007629939624605269
# response relevance llama-13b avg pvalue is 0.2500044815135158, min pvalue is 4.645172639608745e-12, max pvalue is 0.9931766801106002, median pvalue is 0.0657870553318346
# source relevance llama-7b: avg pvalue is 0.15172317273402158, min pvalue is 5.283323636538321e-21, max pvalue is 0.9912272299746749, median pvalue is 0.007571038744153774
# response relevance llama-7b avg pvalue is 0.20835824809064016, min pvalue is 3.4271037346720296e-16, max pvalue is 0.995126170981771, median pvalue is 0.05859991909742693
# source relevance llama-13b avg pvalue is 0.1431978549528656, min pvalue is 3.2849934638787414e-26, max pvalue is 0.9990252283768458, median pvalue is 0.0019153836184763724
# response relevance llama-13b avg pvalue is 0.2354038908940598, min pvalue is 7.570558836475139e-10, max pvalue is 0.9990252283768458, median pvalue is 0.06438060182482645
# source relevance llama-7b: avg pvalue is 0.19536069160235114, min pvalue is 4.568689404077954e-22, max pvalue is 0.9367063571171138, median pvalue is 0.013761686644998845
# response relevance llama-7b avg pvalue is 0.1782231705165216, min pvalue is 2.9146419234230487e-16, max pvalue is 0.995126170981771, median pvalue is 0.02975101011179617
# source relevance llama-13b avg pvalue is 0.16632775415696888, min pvalue is 9.786460035921308e-25, max pvalue is 0.995126170981771, median pvalue is 0.007038658501555111
# response relevance llama-13b avg pvalue is 0.21895165083256948, min pvalue is 3.334372909568335e-09, max pvalue is 0.9697892943606978, median pvalue is 0.075475039023428
# source relevance llama-7b: avg pvalue is 0.16541724105376743, min pvalue is 2.973081980439612e-23, max pvalue is 0.950318781468419, median pvalue is 0.004284075830013268
# response relevance llama-7b avg pvalue is 0.21966910309996376, min pvalue is 3.0253950822933153e-17, max pvalue is 0.9931766801106002, median pvalue is 0.06369629334265713
# source relevance llama-13b avg pvalue is 0.14838878077952486, min pvalue is 7.351111020305598e-30, max pvalue is 0.9892778322113859, median pvalue is 0.012057259125960125
# response relevance llama-13b avg pvalue is 0.25952068192027533, min pvalue is 4.9765419581602176e-12, max pvalue is 0.9990252283768458, median pvalue is 0.10192105569890549
# source relevance llama-7b: avg pvalue is 0.1927270926317566, min pvalue is 1.5305014337788628e-23, max pvalue is 0.9619982760696958, median pvalue is 0.005506828353180851
# response relevance llama-7b avg pvalue is 0.21143134936675245, min pvalue is 1.01792688842049e-14, max pvalue is 0.9931766801106002, median pvalue is 0.06983432963940137
# source relevance llama-13b avg pvalue is 0.14242825071222334, min pvalue is 1.4971574190182006e-26, max pvalue is 0.9814809975952034, median pvalue is 0.008781383043509599
# response relevance llama-13b avg pvalue is 0.24889287344702765, min pvalue is 2.4020610625699485e-09, max pvalue is 0.9814809975952034, median pvalue is 0.10238758884112822
# source relevance llama-7b: avg pvalue is 0.1850715939827689, min pvalue is 4.9682429065338855e-23, max pvalue is 0.9717375286506004, median pvalue is 0.01755086019009004
# response relevance llama-7b avg pvalue is 0.22792280962191946, min pvalue is 1.6956992753387797e-15, max pvalue is 1.0, median pvalue is 0.06437423130330028
# source relevance llama-13b avg pvalue is 0.15444816345971024, min pvalue is 9.175046838255532e-28, max pvalue is 0.9892778322113859, median pvalue is 0.01203455587464937
# response relevance llama-13b avg pvalue is 0.2224494161580142, min pvalue is 6.791251473703548e-15, max pvalue is 0.9736859316010897, median pvalue is 0.08212850577521778
# source relevance llama-7b: avg pvalue is 0.18026134422960674, min pvalue is 1.4664273841585753e-24, max pvalue is 0.9873284984571858, median pvalue is 0.025389747659518742
# response relevance llama-7b avg pvalue is 0.18800313822844192, min pvalue is 5.233551966124838e-16, max pvalue is 0.9717375286506004, median pvalue is 0.03292455366450913
# source relevance llama-13b avg pvalue is 0.19141882270900656, min pvalue is 1.566486767600837e-30, max pvalue is 0.9990252283768458, median pvalue is 0.013967131696460024
# response relevance llama-13b avg pvalue is 0.23746633467273232, min pvalue is 1.3943501787466785e-12, max pvalue is 0.9990252283768458, median pvalue is 0.09713342406522917
# source relevance llama-7b: avg pvalue is 0.1825073661746005, min pvalue is 8.743094319517949e-32, max pvalue is 0.9775831970064603, median pvalue is 0.026636838530021037
# response relevance llama-7b avg pvalue is 0.21399922283601902, min pvalue is 5.460558650594149e-19, max pvalue is 0.9795320362158361, median pvalue is 0.06180403177422267
# source relevance llama-13b avg pvalue is 0.13340314753410687, min pvalue is 1.6649529328997023e-28, max pvalue is 0.9522646908943472, median pvalue is 0.004560804434082449
# response relevance llama-13b avg pvalue is 0.20783764619228232, min pvalue is 1.5361255814246824e-15, max pvalue is 0.9931766801106002, median pvalue is 0.07097583217071685
# source relevance llama-7b: avg pvalue is 0.11150620437050299, min pvalue is 2.820099869431008e-24, max pvalue is 0.8517238360655881, median pvalue is 0.004359584331921724
# response relevance llama-7b avg pvalue is 0.1909259368190601, min pvalue is 2.3039277256450984e-17, max pvalue is 0.9970756909500667, median pvalue is 0.04446667032447638
# source relevance llama-13b avg pvalue is 0.14345691405130792, min pvalue is 1.0551585296678371e-22, max pvalue is 0.9600510592493637, median pvalue is 0.0069956631544552525
# response relevance llama-13b avg pvalue is 0.22031363416788557, min pvalue is 1.4307815731160651e-11, max pvalue is 0.9873284984571858, median pvalue is 0.07272756726354673
# source relevance llama-7b: avg pvalue is 0.16896286120870638, min pvalue is 1.249154379598344e-30, max pvalue is 0.9619982760696958, median pvalue is 0.021770851902161964
# response relevance llama-7b avg pvalue is 0.20879747346988065, min pvalue is 1.4930235261100623e-14, max pvalue is 0.9834300695159244, median pvalue is 0.033427189354026075
# source relevance llama-13b avg pvalue is 0.1637409810155531, min pvalue is 1.0825023908161294e-20, max pvalue is 0.9970756909500667, median pvalue is 0.007327246354893753
# response relevance llama-13b avg pvalue is 0.2570532742212487, min pvalue is 2.6215634485759645e-12, max pvalue is 0.9912272299746749, median pvalue is 0.08212759211959007
# source relevance llama-7b: avg pvalue is 0.19919516791432612, min pvalue is 3.388396361946822e-29, max pvalue is 0.9814809975952034, median pvalue is 0.007259731740076635
# response relevance llama-7b avg pvalue is 0.20785856905375905, min pvalue is 3.006735204466249e-19, max pvalue is 0.9678412403470018, median pvalue is 0.04356635246152654
# source relevance llama-13b avg pvalue is 0.19280321637188322, min pvalue is 2.288653256110039e-25, max pvalue is 0.9892778322113859, median pvalue is 0.03098080038023393
# response relevance llama-13b avg pvalue is 0.2521826754258896, min pvalue is 1.605416769288942e-12, max pvalue is 0.9892778322113859, median pvalue is 0.09884764325582703
# source relevance llama-7b: avg pvalue is 0.13270272998193003, min pvalue is 4.927528379011232e-21, max pvalue is 0.9386499502551384, median pvalue is 0.027935979571663837
# response relevance llama-7b avg pvalue is 0.19975125340978334, min pvalue is 4.2292623596697023e-14, max pvalue is 0.9853792403473814, median pvalue is 0.04671019263792159
# source relevance llama-13b avg pvalue is 0.18079344898601024, min pvalue is 6.494687860612159e-23, max pvalue is 0.9970756909500667, median pvalue is 0.006116264822172323
# response relevance llama-13b avg pvalue is 0.2597949926605688, min pvalue is 7.774345952250472e-15, max pvalue is 0.9931766801106002, median pvalue is 0.09910891089143387
# source relevance llama-7b: avg pvalue is 0.13697529516997137, min pvalue is 2.226564178127394e-14, max pvalue is 0.9076041504611124, median pvalue is 0.029662508220454215
# response relevance llama-7b avg pvalue is 0.18477765072640978, min pvalue is 4.907351979093562e-22, max pvalue is 0.9522646908943472, median pvalue is 0.018509080838669416
# source relevance llama-13b avg pvalue is 0.15572624276392374, min pvalue is 1.3866034640348407e-31, max pvalue is 0.9561573521070761, median pvalue is 0.020954916702417347
# response relevance llama-13b avg pvalue is 0.2565980748804823, min pvalue is 1.6629007021532312e-12, max pvalue is 0.9970756909500667, median pvalue is 0.10579657911690735
# source relevance llama-7b: avg pvalue is 0.1673619024420938, min pvalue is 9.123525702983806e-29, max pvalue is 0.9483731682631666, median pvalue is 0.009103970712506581
# response relevance llama-7b avg pvalue is 0.20192434356725844, min pvalue is 3.311907443698055e-14, max pvalue is 0.9873284984571858, median pvalue is 0.03628476806540265
# source relevance llama-13b avg pvalue is 0.15265610394009768, min pvalue is 3.6854142411328633e-22, max pvalue is 0.9795320362158361, median pvalue is 0.006238482718151649
# response relevance llama-13b avg pvalue is 0.24999685889344864, min pvalue is 4.73291069424225e-14, max pvalue is 0.9795320362158361, median pvalue is 0.11799247800940874
# source relevance llama-7b: avg pvalue is 0.13912768634653522, min pvalue is 5.558678318326746e-16, max pvalue is 0.9834300695159244, median pvalue is 0.010974105588401669
# response relevance llama-7b avg pvalue is 0.19900079256263814, min pvalue is 4.701540976918415e-13, max pvalue is 0.995126170981771, median pvalue is 0.04712665640293215
# source relevance llama-13b avg pvalue is 0.1715545360249754, min pvalue is 1.6386567232734667e-25, max pvalue is 0.995126170981771, median pvalue is 0.013272353613107727
# response relevance llama-13b avg pvalue is 0.21007748742889013, min pvalue is 4.593398902005183e-18, max pvalue is 0.9931766801106002, median pvalue is 0.045965205416006114
# source relevance llama-7b: avg pvalue is 0.1695600238829499, min pvalue is 2.4075269675402967e-27, max pvalue is 0.958104080730776, median pvalue is 0.020192689868890362
# response relevance llama-7b avg pvalue is 0.17591678767312113, min pvalue is 5.558678318326746e-16, max pvalue is 0.9931766801106002, median pvalue is 0.03747764727186956
# source relevance llama-13b avg pvalue is 0.14474988849384698, min pvalue is 6.52128072807953e-25, max pvalue is 0.9853792403473814, median pvalue is 0.005434015474591305
# response relevance llama-13b avg pvalue is 0.2293188673475006, min pvalue is 8.1284555194453e-14, max pvalue is 0.9990252283768458, median pvalue is 0.07962321337860195
# source relevance llama-7b: avg pvalue is 0.15382848532393192, min pvalue is 9.377006686684766e-29, max pvalue is 0.9775831970064603, median pvalue is 0.013232552351188698
# response relevance llama-7b avg pvalue is 0.21328124225875897, min pvalue is 3.559971308658567e-20, max pvalue is 0.9736859316010897, median pvalue is 0.02285720911149918
# source relevance llama-13b avg pvalue is 0.15845188081347483, min pvalue is 1.003804333334265e-25, max pvalue is 0.9834300695159244, median pvalue is 0.007802078179702413
# response relevance llama-13b avg pvalue is 0.20404477065559656, min pvalue is 1.7529317321873934e-12, max pvalue is 0.9873284984571858, median pvalue is 0.051353845248082244
# source relevance llama-7b: avg pvalue is 0.16077405337120612, min pvalue is 2.462064351984351e-19, max pvalue is 0.9853792403473814, median pvalue is 0.054232262059452946
# response relevance llama-7b avg pvalue is 0.1832283348858157, min pvalue is 1.1014109450326243e-18, max pvalue is 0.9931766801106002, median pvalue is 0.0329182866328592
# source relevance llama-13b avg pvalue is 0.17544736667793384, min pvalue is 9.407975550008184e-31, max pvalue is 0.9931766801106002, median pvalue is 0.009347729256128182
# response relevance llama-13b avg pvalue is 0.25594632623867036, min pvalue is 1.18826707470509e-11, max pvalue is 0.995126170981771, median pvalue is 0.09205854275939393
# source relevance llama-7b: avg pvalue is 0.1559841045069434, min pvalue is 1.4805862768428378e-17, max pvalue is 0.9658933782219049, median pvalue is 0.008644325890120173
# response relevance llama-7b avg pvalue is 0.18226735369680214, min pvalue is 5.421777563928364e-17, max pvalue is 0.9736859316010897, median pvalue is 0.022885571807108103
# source relevance llama-13b avg pvalue is 0.17243353202501482, min pvalue is 4.5660128030494315e-25, max pvalue is 0.9970756909500667, median pvalue is 0.0032265443304048506
# response relevance llama-13b avg pvalue is 0.20948627992601349, min pvalue is 1.1684839454875185e-12, max pvalue is 0.9990252283768458, median pvalue is 0.031068884137450865
# source relevance llama-7b: avg pvalue is 0.1613308923643173, min pvalue is 3.580798961759669e-29, max pvalue is 0.9405939089394459, median pvalue is 0.007115391876188903
# response relevance llama-7b avg pvalue is 0.20618421204344284, min pvalue is 3.943139819879668e-15, max pvalue is 0.9736859316010897, median pvalue is 0.05373022287003235
# source relevance llama-13b avg pvalue is 0.18930096357677642, min pvalue is 1.046271994860103e-28, max pvalue is 0.995126170981771, median pvalue is 0.013977965231475629
# response relevance llama-13b avg pvalue is 0.23229032909467914, min pvalue is 1.7529317321873934e-12, max pvalue is 0.9658933782219049, median pvalue is 0.08834013558088241
# source relevance llama-7b: avg pvalue is 0.14076963662370168, min pvalue is 9.533869536147392e-32, max pvalue is 0.9483731682631666, median pvalue is 0.008523250827707086
# response relevance llama-7b avg pvalue is 0.18221508606684217, min pvalue is 2.87624032346016e-19, max pvalue is 0.9717375286506004, median pvalue is 0.0461928522514366
# source relevance llama-13b avg pvalue is 0.16418651174886964, min pvalue is 4.110543420732125e-29, max pvalue is 0.9697892943606978, median pvalue is 0.007148756455416147
# response relevance llama-13b avg pvalue is 0.2207588523430542, min pvalue is 7.570558836475139e-10, max pvalue is 0.9970756909500667, median pvalue is 0.06367888626541027
# source relevance llama-7b: avg pvalue is 0.16557676024942153, min pvalue is 7.358975110622563e-16, max pvalue is 0.9289358705774844, median pvalue is 0.01905744418771957
# response relevance llama-7b avg pvalue is 0.2102355158612782, min pvalue is 5.146809479090955e-22, max pvalue is 0.9873284984571858, median pvalue is 0.050358146356972396
# source relevance llama-13b avg pvalue is 0.16957925623816283, min pvalue is 2.4377929509489085e-28, max pvalue is 0.9678412403470018, median pvalue is 0.004955990455837805
# response relevance llama-13b avg pvalue is 0.23016380909267103, min pvalue is 2.8478580539562904e-14, max pvalue is 0.9990252283768458, median pvalue is 0.10265308894789008
# source relevance llama-7b: avg pvalue is 0.15885087823592017, min pvalue is 4.285521796953937e-21, max pvalue is 0.9697892943606978, median pvalue is 0.009468819873707877
# response relevance llama-7b avg pvalue is 0.2072238828276804, min pvalue is 1.2600588672735336e-15, max pvalue is 0.995126170981771, median pvalue is 0.07309745307515134
# source relevance llama-13b avg pvalue is 0.1632634584592461, min pvalue is 2.765386234684634e-22, max pvalue is 0.9834300695159244, median pvalue is 0.023557002857831997
# response relevance llama-13b avg pvalue is 0.2587213345596304, min pvalue is 8.593765377530592e-14, max pvalue is 0.9736859316010897, median pvalue is 0.11447352543511868
# source relevance llama-7b: avg pvalue is 0.18523972793677754, min pvalue is 1.806586428464753e-14, max pvalue is 0.9076041504611124, median pvalue is 0.03724396778279389
# response relevance llama-7b avg pvalue is 0.18937343107424323, min pvalue is 2.4077704686562337e-18, max pvalue is 0.9561573521070761, median pvalue is 0.027124340728930087
# source relevance llama-13b avg pvalue is 0.1703502958326908, min pvalue is 2.7502576100621582e-24, max pvalue is 0.9853792403473814, median pvalue is 0.013548484166576554
# response relevance llama-13b avg pvalue is 0.2489777814588885, min pvalue is 5.7516910934281435e-09, max pvalue is 0.995126170981771, median pvalue is 0.11559326722526769
# source relevance llama-7b: avg pvalue is 0.1091237469670366, min pvalue is 2.5661719656610532e-23, max pvalue is 0.9912272299746749, median pvalue is 0.0038167771955151994
# response relevance llama-7b avg pvalue is 0.2022544310409503, min pvalue is 4.180567168499582e-15, max pvalue is 0.9970756909500667, median pvalue is 0.02272498431925004
# source relevance llama-13b avg pvalue is 0.19625334353626664, min pvalue is 7.464730722880446e-24, max pvalue is 0.9990252283768458, median pvalue is 0.006909633497129245
# response relevance llama-13b avg pvalue is 0.2408914205257773, min pvalue is 4.3354615400137274e-12, max pvalue is 0.9912272299746749, median pvalue is 0.07875220654621139
# source relevance llama-7b: avg pvalue is 0.180818344388648, min pvalue is 1.1421649712406011e-14, max pvalue is 0.9892778322113859, median pvalue is 0.025458468229771766
# response relevance llama-7b avg pvalue is 0.18186194102099423, min pvalue is 1.093146982953751e-13, max pvalue is 1.0, median pvalue is 0.04065709436168098
# source relevance llama-13b avg pvalue is 0.16863717146365326, min pvalue is 1.649085030180005e-29, max pvalue is 0.9561573521070761, median pvalue is 0.006327951576493607
# response relevance llama-13b avg pvalue is 0.243352821028949, min pvalue is 3.1028599932963615e-13, max pvalue is 0.9970756909500667, median pvalue is 0.06373427300101057
# source relevance llama-7b: avg pvalue is 0.14785644532520634, min pvalue is 2.024979842765062e-18, max pvalue is 0.9678412403470018, median pvalue is 0.0073408356217764485
# response relevance llama-7b avg pvalue is 0.18544124631519335, min pvalue is 4.4320560596669126e-15, max pvalue is 0.9931766801106002, median pvalue is 0.03849794177139461
# source relevance llama-13b avg pvalue is 0.14834953647161855, min pvalue is 1.181506546313038e-26, max pvalue is 0.9873284984571858, median pvalue is 0.009597809823071832
# response relevance llama-13b avg pvalue is 0.2551965556398558, min pvalue is 2.2798943737647213e-12, max pvalue is 0.9912272299746749, median pvalue is 0.11349157794614415
# source relevance llama-7b: avg pvalue is 0.15478045373978536, min pvalue is 4.1230371615871313e-25, max pvalue is 0.9853792403473814, median pvalue is 0.007307481077403777
# response relevance llama-7b avg pvalue is 0.19957217676510428, min pvalue is 2.6081602928814807e-27, max pvalue is 0.9814809975952034, median pvalue is 0.043454827975869526
# source relevance llama-13b avg pvalue is 0.1741694693093579, min pvalue is 5.031833000026121e-31, max pvalue is 0.9853792403473814, median pvalue is 0.013595438396909746
# response relevance llama-13b avg pvalue is 0.22024226477139025, min pvalue is 7.270901246465616e-14, max pvalue is 0.9970756909500667, median pvalue is 0.07040046098932534
# source relevance llama-7b: avg pvalue is 0.16384232598449358, min pvalue is 1.7541196239388636e-20, max pvalue is 0.9970756909500667, median pvalue is 0.007051788501581975
# response relevance llama-7b avg pvalue is 0.21326443596927344, min pvalue is 7.639092303288117e-12, max pvalue is 0.9931766801106002, median pvalue is 0.04459510329642069
# source relevance llama-13b avg pvalue is 0.15198640872668062, min pvalue is 3.786658423565065e-27, max pvalue is 0.958104080730776, median pvalue is 0.005719852502140411
# response relevance llama-13b avg pvalue is 0.258210759075473, min pvalue is 2.5774268193587677e-10, max pvalue is 0.9990252283768458, median pvalue is 0.09592726816312633
# source relevance llama-7b: avg pvalue is 0.16687809336005763, min pvalue is 1.01015807412654e-20, max pvalue is 0.9775831970064603, median pvalue is 0.02515982351688368
# response relevance llama-7b avg pvalue is 0.1953209762076603, min pvalue is 2.9146419234230487e-16, max pvalue is 0.9697892943606978, median pvalue is 0.046040418592136007
# source relevance llama-13b avg pvalue is 0.16749357208028812, min pvalue is 6.1052119975605404e-27, max pvalue is 0.9873284984571858, median pvalue is 0.01351294572854483
# response relevance llama-13b avg pvalue is 0.2407080258619581, min pvalue is 2.8887893578357038e-11, max pvalue is 0.9853792403473814, median pvalue is 0.08122316634529594
# source relevance llama-7b: avg pvalue is 0.12328487147060611, min pvalue is 5.460558650594149e-19, max pvalue is 0.8689999657719885, median pvalue is 0.00514090734765668
# response relevance llama-7b avg pvalue is 0.1751455776532059, min pvalue is 1.8383215910696454e-22, max pvalue is 0.9834300695159244, median pvalue is 0.014410151597064668
# source relevance llama-13b avg pvalue is 0.17782382964165805, min pvalue is 7.594859749012021e-25, max pvalue is 0.9756344915935268, median pvalue is 0.005446802963902979
# response relevance llama-13b avg pvalue is 0.23742587661509604, min pvalue is 7.1346117402313324e-12, max pvalue is 0.995126170981771, median pvalue is 0.09184839287373653
# source relevance llama-7b: avg pvalue is 0.19973137356333304, min pvalue is 2.499704661612199e-29, max pvalue is 0.9561573521070761, median pvalue is 0.026208225592479047
# response relevance llama-7b avg pvalue is 0.15728091450522075, min pvalue is 1.8292837276737529e-13, max pvalue is 0.9561573521070761, median pvalue is 0.018753255684989492
# source relevance llama-13b avg pvalue is 0.16912964664717972, min pvalue is 5.978684467351175e-26, max pvalue is 0.9892778322113859, median pvalue is 0.0067093997701512115
# response relevance llama-13b avg pvalue is 0.27716916385352613, min pvalue is 1.7314871703752638e-13, max pvalue is 0.9970756909500667, median pvalue is 0.14771779709744298
# source relevance llama-7b: avg pvalue is 0.15755537955029442, min pvalue is 3.9177966644815286e-25, max pvalue is 0.9347631410579703, median pvalue is 0.04245712718054919
# response relevance llama-7b avg pvalue is 0.1655170347957298, min pvalue is 6.6858163367384665e-22, max pvalue is 0.9775831970064603, median pvalue is 0.02540306558169762
# source relevance llama-13b avg pvalue is 0.1671873170821914, min pvalue is 3.443781312287928e-23, max pvalue is 0.995126170981771, median pvalue is 0.011684498732603577
# response relevance llama-13b avg pvalue is 0.22610365176169317, min pvalue is 1.290532120569184e-13, max pvalue is 0.9658933782219049, median pvalue is 0.05342761534135983
# source relevance llama-7b: avg pvalue is 0.173572670821042, min pvalue is 2.5046707724179742e-21, max pvalue is 0.995126170981771, median pvalue is 0.004302415603033207
# response relevance llama-7b avg pvalue is 0.23449272188563783, min pvalue is 8.954092234302123e-13, max pvalue is 0.9892778322113859, median pvalue is 0.08834678558958435
# source relevance llama-13b avg pvalue is 0.16198575034970739, min pvalue is 2.735977335949005e-26, max pvalue is 0.9834300695159244, median pvalue is 0.007908583785099562
# response relevance llama-13b avg pvalue is 0.24068029644603228, min pvalue is 2.910299600469035e-12, max pvalue is 0.995126170981771, median pvalue is 0.10632467559584816

# %%
# 散点图
import matplotlib.pyplot as plt
plt.rcParams['font.size'] = 20

# 绘制散点图
plt.scatter(['R1']*len(mannwhitneyu_median_hs), mannwhitneyu_median_hs, color='lightblue', label='R1:Rprompt(Llama-2-7b-chat)')
plt.scatter(['R2']*len(mannwhitneyu_median_nonhs), mannwhitneyu_median_nonhs, color='#0080FF', label='R2:Rresponse(Llama-2-7b-chat)')
plt.scatter(['R3']*len(mannwhitneyu_median_hs2), mannwhitneyu_median_hs2, color='lightgreen', label='R3:Rprompt(Llama-2-13b-chat)')
plt.scatter(['R4']*len(mannwhitneyu_median_nonhs2), mannwhitneyu_median_nonhs2, color='green', label='R4:Rresponse(Llama-2-13b-chat)')

# 设置横坐标为字符串
# plt.xticks(ticks=range(len(x_labels)), labels=x_labels)

# 设置图表标题和坐标轴标签
plt.title('Mann-Whitney U Test')
plt.xlabel('Hallucination vs Normal')
plt.ylabel('pvalue')

# 添加图例
plt.legend(loc='center right', bbox_to_anchor=(1.03, -0.5))
plt.savefig('../pdf/mannwhitneyu_median_pvalue.pdf', bbox_inches='tight')

# 显示图表
plt.show()

# %%
import matplotlib.pyplot as plt

plt.rcParams['font.size'] = 20

h_contributions_s_mean=normalize(h_contributions_s_mean)
nonh_contributions_s_mean=normalize(nonh_contributions_s_mean)
h_contributions_d_mean=normalize(h_contributions_d_mean)
nonh_contributions_d_mean=normalize(nonh_contributions_d_mean)
# 创建图形
fig, axs = plt.subplots(2, 2, figsize=(16, 16))
# 设置标题
axs[0][0].set_title('Source Relevance(LlaMA-7B)')
axs[0][0].set_xlabel('Prompt Tokens')
axs[0][0].set_ylabel('Relevance')
# 归一化矩阵
axs[0][0].plot(range(len(h_contributions_s_mean)), h_contributions_s_mean,label='Hallucinated Samples')
axs[0][0].plot(range(len(nonh_contributions_s_mean)), nonh_contributions_s_mean,label='Normal Samples')
axs[0][0].legend()

axs[0][1].set_title('Response Relevance(LlaMA-7B)')
axs[0][1].set_xlabel('Response Tokens')
axs[0][1].set_ylabel('Relevance')
# 归一化矩阵
axs[0][1].plot(range(len(h_contributions_d_mean)), h_contributions_d_mean,label='Hallucinated Samples')
axs[0][1].plot(range(len(nonh_contributions_d_mean)), nonh_contributions_d_mean,label='Normal Samples')
axs[0][1].legend()

h_contributions_s_mean2=normalize(h_contributions_s_mean2)
nonh_contributions_s_mean2=normalize(nonh_contributions_s_mean2)
h_contributions_d_mean2=normalize(h_contributions_d_mean2)
nonh_contributions_d_mean2=normalize(nonh_contributions_d_mean2)

# 设置标题
axs[1][0].set_title('Source Relevance(LlaMA-13B)')
axs[1][0].set_xlabel('Prompt Tokens')
axs[1][0].set_ylabel('Relevance')
# 归一化矩阵
axs[1][0].plot(range(len(h_contributions_s_mean2)), h_contributions_s_mean2,label='Hallucinated Samples')
axs[1][0].plot(range(len(nonh_contributions_s_mean2)), nonh_contributions_s_mean2,label='Normal Samples')
axs[1][0].legend()

axs[1][1].set_title('Response Relevance(LlaMA-13B)')
axs[1][1].set_xlabel('Response Tokens')
axs[1][1].set_ylabel('Relevance')
# 归一化矩阵
axs[1][1].plot(range(len(h_contributions_d_mean2)), h_contributions_d_mean2,label='Hallucinated Samples')
axs[1][1].plot(range(len(nonh_contributions_d_mean2)), nonh_contributions_d_mean2,label='Normal Samples')
axs[1][1].legend()

plt.savefig('../pdf/line.pdf', format='pdf')
plt.show()

# %%
from matplotlib.colors import LinearSegmentedColormap
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['font.size'] = 20

# 创建图形
fig, axs = plt.subplots(2, 2, figsize=(16, 16))
# 归一化矩阵

# 绘制热力图
im = axs[0][0].imshow(normalize(h_contributions_mean), cmap="Blues")  

# 设置标题
axs[0][0].set_title('Hallucination(LlaMA-7B)')
axs[0][0].set_xlabel('Prompt Tokens')
axs[0][0].set_ylabel('Response Tokens')
fig.colorbar(im, ax=axs[0][0])
# 绘制热力图
im2 = axs[0][1].imshow(normalize(nonh_contributions_mean), cmap="Blues")

# 设置标题
axs[0][1].set_title('Normal(LlaMA-7B)')
axs[0][1].set_xlabel('Prompt Tokens')
axs[0][1].set_ylabel('Response Tokens')

# 添加颜色条
fig.colorbar(im2, ax=axs[0][1])

# 绘制热力图
im3 = axs[1][0].imshow(normalize(h_contributions_mean2), cmap="Blues")

# 设置标题
axs[1][0].set_title('Hallucination(LlaMA-13B)')
axs[1][0].set_xlabel('Prompt Tokens')
axs[1][0].set_ylabel('Response Tokens')

# 添加颜色条
fig.colorbar(im3, ax=axs[1][0])


# 绘制热力图
im3 = axs[1][1].imshow(normalize(nonh_contributions_mean2), cmap="Blues")

# 设置标题
axs[1][1].set_title('Normal(LlaMA-13B)')
axs[1][1].set_xlabel('Prompt Tokens')
axs[1][1].set_ylabel('Response Tokens')

# 添加颜色条
fig.colorbar(im3, ax=axs[1][1])


# 显示图形
plt.savefig("../pdf/hotmap.pdf")
plt.show()
